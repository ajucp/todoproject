# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+20]  # Extract 20 bases
        if subseq.endswith(('AGG', 'TGG', 'CGG', 'GGG')):
            subsequences.append(subseq)
    return subsequences

# Sample input sequence
sequence = "..."

subsequences = extract_subsequences(sequence)
for subseq in subsequences:
    print(subseq)
# Out:
# GGGGATCTGCTGCAGCAAGG
# GATCTGCTGCAGCAAGGCGG
# TGCAGCAAGGCGGCAGCAGG
# GCAGCAAGGCGGCAGCAGGG
# CAGCAAGGCGGCAGCAGGGG
# GGCGGCAGCAGGGGAGCTGG
# GGAGCTGGACGACGACGAGG
# GAGCTGGACGACGACGAGGG
# GGACGACGACGAGGGCTTGG
# GACGACGACGAGGGCTTGGG
# AGGGCTTGGGCTTCCCATGG
# TGTTCCACAGCCACCTCTGG
# GTTCCACAGCCACCTCTGGG
# CACCTCTGGGCCAGCGCCGG
# CTCCGTGCACACCAAGCAGG
# TCCGTGCACACCAAGCAGGG
# TGCACACCAAGCAGGGATGG
# CACCAAGCAGGGATGGAAGG
# ACCAAGCAGGGATGGAAGGG
# ATGGAAGGGTGCCAACCAGG
# CGCCATGACCGTCTCCCAGG
# GTCTCCCAGGACTTTGCTGG
# GACTTTGCTGGCCAAAAAGG
# AAAGGCCACATCTTCTGCGG
# TTCTGCGGAGTGTTTGATGG
# TCTGCGGAGTGTTTGATGGG
# GGAGTGTTTGATGGGCATGG
# GATGGGCATGGCCCTCTTGG
# GCTTTGAAACCGAAAAGTGG
# CTTTGAAACCGAAAAGTGGG
# TTTGAAACCGAAAAGTGGGG
# TTGAAACCGAAAAGTGGGGG
# CTCAAGCAACACAGATTTGG
# GCCAGCTGTTGTCCACTTGG
# CGTGAAGACTTTTGAGCTGG
# GAAGACTTTTGAGCTGGTGG
# TTTTGAGCTGGTGGACGAGG
# TGGTGGACGAGGAACTGAGG
# GAACTGAGGCAACATTCAGG
# ATAGACTGCATTTGTAGTGG
# AGTCGCTGCTGTTAGACAGG
# GTCGCTGCTGTTAGACAGGG
# CTTGATCGTTGCCAATTTGG
# ...

# %%
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC

# Read the input sequence from the text file
with open("input_sequence.txt", "r") as file:
    sequence = file.read()

# Extract all 20-base subsequences that end with "NGG" (where N can be any nucleotide)
subsequences = re.findall(r'[ATCG]{17}[ATCG]{1}GG', sequence)

# Prepare the data for training the machine learning model
X = [subsequence[:-3] for subsequence in subsequences]  # Input features (remove the "NGG" ending)
y = [1 if subsequence.endswith(('AGG', 'TGG', 'CGG', 'GGG')) else 0 for subsequence in subsequences]  # Target labels

# Vectorize the input features
vectorizer = CountVectorizer(ngram_range=(2, 2))
X_vectorized = vectorizer.fit_transform(X)

# Train the machine learning model
model = SVC()
model.fit(X_vectorized, y)

# Extract subsequences from the input sequence and predict their class using the trained model
extracted_subsequences = []
for i in range(len(sequence)-19):
    subsequence = sequence[i:i+20]
    subsequence_vectorized = vectorizer.transform([subsequence[:-3]])
    prediction = model.predict(subsequence_vectorized)
    if prediction == 1:
        extracted_subsequences.append(subsequence[:-3])

# Print the extracted subsequences
for subsequence in extracted_subsequences:
    print(subsequence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <cell line: 18>()
#      16 # Vectorize the input features
#      17 vectorizer = CountVectorizer(ngram_range=(2, 2))
# ---> 18 X_vectorized = vectorizer.fit_transform(X)
#      20 # Train the machine learning model
#      21 model = SVC()
#
# File c:\users\ajmal\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
#    1383                 " is True. These entries will not"
#    1384                 " be matched with any documents"
#    1385             )
#    1386             break
# ...

# %%
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC

# Read the input sequence from the text file
with open("input_sequence.txt", "r") as file:
    sequence = file.read()

# Extract all 20-base subsequences that end with "NGG" (where N can be any nucleotide)
subsequences = re.findall(r'[ATCG]{17}[ATCG]{1}GG', sequence)

# Prepare the data for training the machine learning model
X = [subsequence[:-3] for subsequence in subsequences if len(subsequence) >= 10]  # Input features (remove the "NGG" ending)
y = [1 if subsequence.endswith(('AGG', 'TGG', 'CGG', 'GGG')) else 0 for subsequence in subsequences if len(subsequence) >= 10]  # Target labels

# Vectorize the input features
vectorizer = CountVectorizer(ngram_range=(3, 3))
X_vectorized = vectorizer.fit_transform(X)

# Train the machine learning model
model = SVC()
model.fit(X_vectorized, y)

# Extract subsequences from the input sequence and predict their class using the trained model
extracted_subsequences = []
for i in range(len(sequence)-19):
    subsequence = sequence[i:i+20]
    if len(subsequence) >= 10:
        subsequence_vectorized = vectorizer.transform([subsequence[:-3]])
        prediction = model.predict(subsequence_vectorized)
        if prediction == 1:
            extracted_subsequences.append(subsequence[:-3])

# Print the extracted subsequences
for subsequence in extracted_subsequences:
    print(subsequence)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [13], in <cell line: 18>()
#      16 # Vectorize the input features
#      17 vectorizer = CountVectorizer(ngram_range=(3, 3))
# ---> 18 X_vectorized = vectorizer.fit_transform(X)
#      20 # Train the machine learning model
#      21 model = SVC()
#
# File c:\users\ajmal\appdata\local\programs\python\python39\lib\site-packages\sklearn\feature_extraction\text.py:1388, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1380             warnings.warn(
#    1381                 "Upper case characters found in"
#    1382                 " vocabulary while 'lowercase'"
#    1383                 " is True. These entries will not"
#    1384                 " be matched with any documents"
#    1385             )
#    1386             break
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 20 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq)
    return subsequences

# Read sequence from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequence = file.read().strip()

subsequences = extract_subsequences(sequence)
for subseq in subsequences:
    print(subseq)
# Out:
# GGGGATCTGCTGCAGCAAGGCGG
# TGCTGCAGCAAGGCGGCAGCAGG
# GCTGCAGCAAGGCGGCAGCAGGG
# CTGCAGCAAGGCGGCAGCAGGGG
# CAAGGCGGCAGCAGGGGAGCTGG
# AGGGGAGCTGGACGACGACGAGG
# GGGGAGCTGGACGACGACGAGGG
# GCTGGACGACGACGAGGGCTTGG
# CTGGACGACGACGAGGGCTTGGG
# ACGAGGGCTTGGGCTTCCCATGG
# ACCTGTTCCACAGCCACCTCTGG
# CCTGTTCCACAGCCACCTCTGGG
# AGCCACCTCTGGGCCAGCGCCGG
# CGTCTCCGTGCACACCAAGCAGG
# GTCTCCGTGCACACCAAGCAGGG
# CCGTGCACACCAAGCAGGGATGG
# GCACACCAAGCAGGGATGGAAGG
# CACACCAAGCAGGGATGGAAGGG
# GGGATGGAAGGGTGCCAACCAGG
# GGACGCCATGACCGTCTCCCAGG
# ACCGTCTCCCAGGACTTTGCTGG
# CAGGACTTTGCTGGCCAAAAAGG
# CAAAAAGGCCACATCTTCTGCGG
# ATCTTCTGCGGAGTGTTTGATGG
# TCTTCTGCGGAGTGTTTGATGGG
# TGCGGAGTGTTTGATGGGCATGG
# TTTGATGGGCATGGCCCTCTTGG
# TCTGCTTTGAAACCGAAAAGTGG
# CTGCTTTGAAACCGAAAAGTGGG
# TGCTTTGAAACCGAAAAGTGGGG
# GCTTTGAAACCGAAAAGTGGGGG
# TCCCTCAAGCAACACAGATTTGG
# AGAGCCAGCTGTTGTCCACTTGG
# ATTCGTGAAGACTTTTGAGCTGG
# CGTGAAGACTTTTGAGCTGGTGG
# GACTTTTGAGCTGGTGGACGAGG
# AGCTGGTGGACGAGGAACTGAGG
# GAGGAACTGAGGCAACATTCAGG
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 20 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read sequence from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequence = file.read().strip()

subsequences = extract_subsequences(sequence)
for subseq in subsequences:
    print(subseq)
# Out:
# GGGGATCTGCTGCAGCAAGG
# TGCTGCAGCAAGGCGGCAGC
# GCTGCAGCAAGGCGGCAGCA
# CTGCAGCAAGGCGGCAGCAG
# CAAGGCGGCAGCAGGGGAGC
# AGGGGAGCTGGACGACGACG
# GGGGAGCTGGACGACGACGA
# GCTGGACGACGACGAGGGCT
# CTGGACGACGACGAGGGCTT
# ACGAGGGCTTGGGCTTCCCA
# ACCTGTTCCACAGCCACCTC
# CCTGTTCCACAGCCACCTCT
# AGCCACCTCTGGGCCAGCGC
# CGTCTCCGTGCACACCAAGC
# GTCTCCGTGCACACCAAGCA
# CCGTGCACACCAAGCAGGGA
# GCACACCAAGCAGGGATGGA
# CACACCAAGCAGGGATGGAA
# GGGATGGAAGGGTGCCAACC
# GGACGCCATGACCGTCTCCC
# ACCGTCTCCCAGGACTTTGC
# CAGGACTTTGCTGGCCAAAA
# CAAAAAGGCCACATCTTCTG
# ATCTTCTGCGGAGTGTTTGA
# TCTTCTGCGGAGTGTTTGAT
# TGCGGAGTGTTTGATGGGCA
# TTTGATGGGCATGGCCCTCT
# TCTGCTTTGAAACCGAAAAG
# CTGCTTTGAAACCGAAAAGT
# TGCTTTGAAACCGAAAAGTG
# GCTTTGAAACCGAAAAGTGG
# TCCCTCAAGCAACACAGATT
# AGAGCCAGCTGTTGTCCACT
# ATTCGTGAAGACTTTTGAGC
# CGTGAAGACTTTTGAGCTGG
# GACTTTTGAGCTGGTGGACG
# AGCTGGTGGACGAGGAACTG
# GAGGAACTGAGGCAACATTC
# GGAATAGACTGCATTTGTAG
# TGCAGTCGCTGCTGTTAGAC
# GCAGTCGCTGCTGTTAGACA
# TCACTTGATCGTTGCCAATT
# CACTTGATCGTTGCCAATTT
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence
result = {}
for sequence in sequences:
    subsequences = extract_subsequences(sequence)
    result[sequence] = subsequences

# Save subsequences to separate files
for sequence, subsequences in result.items():
    output_filename = f"{sequence[:10]}_subsequences.txt"  # Customize the output filename as per your preference
    with open(output_filename, "w") as file:
        file.write('\n'.join(subsequences))
        print(f"Subsequences for {sequence} saved in {output_filename}")
# Out:
# Subsequences for ... saved in ATGGGGATCT_subsequences.txt
# Subsequences for ... saved in ATGGGGATCT_subsequences.txt

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

# Print the dictionary with parent sequence index as keys and corresponding subsequences as values
for idx, subsequences in result.items():
    print(f"Parent sequence index: {idx}")
    print(f"Subsequences: {subsequences}")
    print()  # Print a blank line for readability
# Out:
# Parent sequence index: 0
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

    
# Print the dictionary with parent sequence index as keys and corresponding subsequences as values
for idx, subsequences in result.items():
    print(f"Parent sequence index: {idx}")
    print(f"Subsequences: {subsequences}")
    print(f"count : {len(subsequences)}")
    print()  # Print a blank line for readability
# Search for subsequences in all other parent sequences and save in a list
target_subsequences = set()
for idx, subsequences in result.items():
    for subseq in subsequences:
        found = False
        for other_idx, other_subsequences in result.items():
            if subseq in other_subsequences:
                found = True
                break
        if found:
            target_subsequences.add(subseq)

            


# Print the list of subsequences present in all other parent sequences
print(f"Subsequences present in all other parent sequences: {target_subsequences}")
print(f"count: {len(target_subsequences)}")
# Out:
# Parent sequence index: 0
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence_for_mRNA.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

# Get the set of subsequences from the first parent sequence
target_subsequences = set(result[0])
print(f"Count: {target_subsequences.intersection(set(subsequences))}")
# Find subsequences present in all other parent sequences
for idx, subsequences in result.items():
    target_subsequences = target_subsequences.intersection(set(subsequences))

# Print the list of subsequences present in all parent sequences
print(f"Subsequences present in all parent sequences: {target_subsequences}")
print(f"Count: {len(target_subsequences)}")
# Out:
# Count: set()
# Subsequences present in all parent sequences: set()
# Count: 0

# %%
test = 'GGGGATCTGCTGCAGCAAGG'
sample = ['GGGGATCTGCTGCAGCAAGG', 'TGCTGCAGCAAGGCGGCAGC', 'GCTGCAGCAAGGCGGCAGCA', 'CTGCAGCAAGGCGGCAGCAG', 'CAAGGCGGCAGCAGGGGAGC', 'AGGGGAGCTGGACGACGACG', 'GGGGAGCTGGACGACGACGA', 'GCTGGACGACGACGAGGGCT', 'CTGGACGACGACGAGGGCTT', 'ACGAGGGCTTGGGCTTCCCA', 'ACCTGTTCCACAGCCACCTC', 'CCTGTTCCACAGCCACCTCT', 'AGCCACCTCTGGGCCAGCGC', 'CGTCTCCGTGCACACCAAGC', 'GTCTCCGTGCACACCAAGCA', 'CCGTGCACACCAAGCAGGGA', 'GCACACCAAGCAGGGATGGA', 'CACACCAAGCAGGGATGGAA', 'GGGATGGAAGGGTGCCAACC', 'GGACGCCATGACCGTCTCCC', 'ACCGTCTCCCAGGACTTTGC', 'CAGGACTTTGCTGGCCAAAA', 'CAAAAAGGCCACATCTTCTG', 'ATCTTCTGCGGAGTGTTTGA', 'TCTTCTGCGGAGTGTTTGAT', 'TGCGGAGTGTTTGATGGGCA', 'TTTGATGGGCATGGCCCTCT', 'TCTGCTTTGAAACCGAAAAG', 'CTGCTTTGAAACCGAAAAGT', 'TGCTTTGAAACCGAAAAGTG', 'GCTTTGAAACCGAAAAGTGG', 'TCCCTCAAGCAACACAGATT', 'AGAGCCAGCTGTTGTCCACT', 'ATTCGTGAAGACTTTTGAGC', 'CGTGAAGACTTTTGAGCTGG']
print(sample.count('GGGGATCTGCTGCAGCAAGG'))
if test in target_subsequences:
    print('ddsdsd')
# Out:
# 1
# ddsdsd

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

    
# Print the dictionary with parent sequence index as keys and corresponding subsequences as values
for idx, subsequences in result.items():
    print(f"Parent sequence index: {idx}")
    print(f"Subsequences: {subsequences}")
    print(f"count : {len(subsequences)}")
    print()  # Print a blank line for readability
# Search for subsequences in all other parent sequences and save in a list
target_subsequences = []
for idx, subsequences in result.items():
    for subseq in subsequences:
        found = False
        for other_idx, other_subsequences in result.items():
            if subseq in other_subsequences:
                found = True
                break
        if found:
            target_subsequences.append(subseq)

            


# Print the list of subsequences present in all other parent sequences
print(f"Subsequences present in all other parent sequences: {target_subsequences}")
print(f"count: {len(target_subsequences)}")
# Out:
# Parent sequence index: 0
# ...

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

# Read DNA sequences from file
filename = "input_sequence_for_mRNA.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

# Get the set of subsequences from the first parent sequence
target_subsequences = set(result[0])
# print(f"Count: {target_subsequences.intersection(set(subsequences))}")
# print(target_subsequences)
# Find subsequences present in all other parent sequences
for idx, subsequences in result.items():
    target_subsequences = target_subsequences.intersection(set(subsequences))

# Print the list of subsequences present in all parent sequences
print(f"Subsequences present in all parent sequences: {target_subsequences}")
print(target_subsequences)
print(f"Count: {len(target_subsequences)}")
# Out:
# Subsequences present in all parent sequences: set()
# set()
# Count: 0

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

def calculate_similarity(string1, string2):
    set1 = set(string1)
    set2 = set(string2)
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    similarity = intersection / union
    return similarity



def check_similarity(string1, string2, threshold=0.8):
    similarity = calculate_similarity(string1, string2)
    if similarity > threshold:
        return True
    else:
        return False


def check_strings_present(list_of_lists):
    result = []
    for i, sublist in enumerate(list_of_lists):
        other_lists = list_of_lists[:i] + list_of_lists[i+1:]  # Exclude the current sublist
        for sequence in sublist:
            for checking_list in other_lists:
                for checking_sequence in checking_list:
                    if check_similarity(sequence,checking_sequence):
                        result.append(sequence)
    return result

# Read DNA sequences from file
filename = "input_sequence_for_mRNA.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences

    
# Print the dictionary with parent sequence index as keys and corresponding subsequences as values
# for idx, subsequences in result.items():
#     print(f"Parent sequence index: {idx}")
#     print(f"Subsequences: {subsequences}")
#     print(f"count : {len(subsequences)}")
    print()  # Print a blank line for readability
# Search for subsequences in all other parent sequences and save in a list
target_subsequences = check_strings_present(list(result.values()))


            


# # Print the list of subsequences present in all other parent sequences
print(f"Subsequences present in all other parent sequences: {target_subsequences}")
print(f"count: {len(target_subsequences)}")
print(f"count: ")

# %%
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

def calculate_similarity(string1, string2):
    len1 = len(string1)
    len2 = len(string2)
    
    # Calculate the length of the shorter string
    min_len = min(len1, len2)
    
    # Calculate the number of matching characters from the start
    match_count = 0
    for i in range(min_len):
        if string1[i] == string2[i]:
            match_count += 1
        else:
            break
    
    # Calculate the similarity percentage
    similarity = (match_count / min_len) * 100
    
    return similarity



def check_strings_present(list_of_lists):
    result = []
    for i, sublist in enumerate(list_of_lists):
        other_lists = list_of_lists[:i] + list_of_lists[i+1:]  # Exclude the current sublist
        for sequence in sublist:
            for checking_list in other_lists:
                for checking_sequence in checking_list:
                    if calculate_similarity(sequence,checking_sequence) > 90:
                        result.append(sequence)
    return result

# Read DNA sequences from file
filename = "input_sequence.txt"
with open(filename, "r") as file:
    sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary
result = {}
for idx, sequence in enumerate(sequences):
    subsequences = extract_subsequences(sequence)
    result[idx] = subsequences
total_count_of_seq = 0
print("count: ")   
# Print the dictionary with parent sequence index as keys and corresponding subsequences as values
for idx, subsequences in result.items():
    print(f"Parent sequence index: {idx}")
    print(f"Subsequences: {subsequences}")
    print(f"count : {len(subsequences)}")
    total_count_of_seq = total_count_of_seq + len(subsequences)
    print()  # Print a blank line for readability
# Search for subsequences in all other parent sequences and save in a list
print("total no of sequences : ",total_count_of_seq)
target_subsequences = check_strings_present(list(result.values()))
print("------------------------------------------------------------------------------- ")
print("------------------------------------------------------------------------------- ")

            


# # # Print the list of subsequences present in all other parent sequences
# print(f"Subsequences present in all other parent sequences: {target_subsequences}")
print(f"count of result: {len(target_subsequences)}")
# Out:
# count:
# Parent sequence index: 0
# ...

# %%
last_result = set(target_subsequences)
print(len(last_result))
print(last_result)
# Out:
# 1251
# ...

# %%
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.svm import SVC
def extract_subsequences(sequence):
    subsequences = []
    for i in range(len(sequence) - 23):  # Check for subsequences of length 23 (including "NGG")
        subseq = sequence[i:i+23]  # Extract 23 bases
        if subseq[-3:] in ['AGG', 'TGG', 'CGG', 'GGG']:
            subsequences.append(subseq[:20])
    return subsequences

def calculate_similarity(string1, string2):
    len1 = len(string1)
    len2 = len(string2)
    
    # Calculate the length of the shorter string
    min_len = min(len1, len2)
    
    # Calculate the number of matching characters from the start
    match_count = 0
    for i in range(min_len):
        if string1[i] == string2[i]:
            match_count += 1
        else:
            break
    
    # Calculate the similarity percentage
    similarity = (match_count / min_len) * 100
    
    return similarity



def check_strings_present(list_of_lists):
    result = []
    for i, sublist in enumerate(list_of_lists):
        other_lists = list_of_lists[:i] + list_of_lists[i+1:]  # Exclude the current sublist
        for sequence in sublist:
            for checking_list in other_lists:
                for checking_sequence in checking_list:
                    if calculate_similarity(sequence,checking_sequence) > 90:
                        result.append(sequence)
    return result

# Read DNA sequences from file
# filename = "input_sequence.txt"
# with open(filename, "r") as file:
#     sequences = file.read().strip().split('\n')

# Extract subsequences for each DNA sequence and store in a dictionary

def genome_extract(sequences):
    sequences = sequences.strip().split('\n')
    result = {}
    for idx, sequence in enumerate(sequences):
        subsequences = extract_subsequences(sequence)
        result[idx] = subsequences
    total_count_of_seq = 0
    print("count: ")   
    # Print the dictionary with parent sequence index as keys and corresponding subsequences as values
    for idx, subsequences in result.items():
        print(f"Parent sequence index: {idx}")
        print(f"Subsequences: {subsequences}")
        print(f"count : {len(subsequences)}")
        total_count_of_seq = total_count_of_seq + len(subsequences)
        print()  # Print a blank line for readability
    # Search for subsequences in all other parent sequences and save in a list
    print("total no of sequences : ",total_count_of_seq)
    target_subsequences = check_strings_present(list(result.values()))
    print("------------------------------------------------------------------------------- ")
    print("------------------------------------------------------------------------------- ")

                


    # # # Print the list of subsequences present in all other parent sequences
    # print(f"Subsequences present in all other parent sequences: {target_subsequences}")
    print(f"count of result: {len(target_subsequences)}")
    last_result = set(target_subsequences)
    print(len(last_result))
    print(last_result)
    return last_resultS
